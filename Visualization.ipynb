# %%
import pandas as pd

df = pd.read_csv("./Avocado.csv")
df['Date'] = pd.to_datetime(df['Date'])

albany_df = df[df['region'] == 'Albany']
albany_df.set_index("Date", inplace=True)
# albany_df.head()
albany_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_df.head(23)

albany_df["DayimPrice"].plot()
# Out:
# <Axes: xlabel='Date'>
